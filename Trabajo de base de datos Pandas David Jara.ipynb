# %%
#Trabajo de Base de Datos en Pandas.
#Elaborado por: David Jara.
# Fecha: 29 enero de 2020

import numpy as np
import pandas as pd

def doblelin():
    print("**********************************************************************")
    print("**********************************************************************")
    return
#**********************************************************************************
#**********************************************************************************
#                         A.0 CARGA DE LOS ARCHIVOS CVS
#**********************************************************************************
#**********************************************************************************

titulos = pd.read_csv("data/titles.csv") #Para leer un archivo. csv ubicado en la carpeta "data"
#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# imprime los primeros 10 títulos
print("**********************************************************************")
print("**********************************************************************")
print("\t TITULOS")
print(titulos.head(10))

#**********************************************************************************
#**********************************************************************************
#                         A.1 NUMERO DE TÍTULOS
#**********************************************************************************
#**********************************************************************************

doblelin()
print("El número de títulos es\t",len(titulos))

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()

#**********************************************************************************
#**********************************************************************************
#                         A.2 # Cual fue la primer pelicula hecha titulada "Romeo and Juliet" ?
#**********************************************************************************
#**********************************************************************************

print("Cuál fue la primera película titulada 'Romeo and Juliet'")
print(titulos[titulos.title == "Romeo and Juliet"].sort_values('year').head(2))

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()

#**********************************************************************************
#**********************************************************************************
#                         A.3 Listar todas las peliculas que contengan la palabra "Exorcist"
                              # ordenadas de la mas vieja a la mas reciente.
#**********************************************************************************
#**********************************************************************************

print("Listar todas las películas que contengan la palabra 'Exorcist' ")
A = titulos[titulos.title.str.contains("Exorcist")].sort_values(by = "year",ascending = False)
print(A)

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()

#**********************************************************************************
#**********************************************************************************
#                         A.4 # Cuántas películas fueron hechas en el año 1950                               
#**********************************************************************************
#**********************************************************************************

print("¿Cuántas películas fueron hechas en el año 1950?",end = " ")
A=titulos[titulos["year"].isin(["1950"])] #En la columna titulos["year"] buscar ["1950"] e imprimir las filas de titulos 
#print(A)                                  # donde se encuentren estos valores
print(len(A))

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()

#**********************************************************************************
#**********************************************************************************
#                         A.4 # Cuántas películas fueron hechas en el año 1950. Otro método.                               
#**********************************************************************************
#**********************************************************************************

print("¿Cuántas películas fueron hechas en el año 1950?",end = " ")
print(len(titulos[titulos.year == 1950]))

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()

#**********************************************************************************
#**********************************************************************************
#                         A.5 Cuantas peliculas fueron hechas de 1950 a 1959                               
#**********************************************************************************
#**********************************************************************************

# ordenar el dataframe en función del año
A = titulos.sort_values(by = "year",ascending = True)

#Insertamos una columna "indices" en el DataFrame ya ordenado.
B = list(np.array(range(0,len(A),1)))
A["indice"] = B

#Determinar la primera pelicula hecha en 1950
A[A.year >= 1950].head(1) #indice = 33788

#Determinar la última película hecha en 1959
A[A.year <= 1959].tail(5) #indice = 46393

#La diferencia entre los índices nos dará la cantidad de películas entre 1950 y 1959
print("¿Cuantas peliculas fueron hechas de 1950 a 1959?",end = " ")
print(len(titulos[(titulos.year >= 1950) & (titulos.year <=1959)]))

#**********************************************************************************
#**********************************************************************************
#                         A.6 # En que años alguna pelicula llamada "Batman" se presento                               
#**********************************************************************************
#**********************************************************************************

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()
print("En que años alguna pelicula llamada 'Batman' se presento")
print(titulos[titulos.title == "Batman"])

#**********************************************************************************
#**********************************************************************************
#                         A.7 Cuántas películas fueron hechas en el año 1980.                               
#**********************************************************************************
#**********************************************************************************

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()
print("¿Cuántas películas fueron hechas en el año 1980?",end = " ")
print(len(titulos[titulos.year == 1980]))

#**********************************************************************************
#**********************************************************************************
#                         A.8 (5) primeras Películas del año 1983                               
#**********************************************************************************
#**********************************************************************************

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()

print("5 primeras Películas del año 1983")
print(titulos[titulos.year == 1983].head(5))

#**********************************************************************************
#**********************************************************************************
#                         A.9 (10) ultimas Películas del año 1973                               
#**********************************************************************************
#**********************************************************************************

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()

print("10 ultimas Películas del año 1973")
print(titulos[titulos.year == 1973].tail(10))

#**********************************************************************************
#**********************************************************************************
#                         B.1 Carga del archivo elenco.csv                               
#**********************************************************************************
#**********************************************************************************

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()

elenco = pd.read_csv("data/cast.csv",encoding = 'utf-8')
print("**********************************************************************")
print("\tELENCO")
elenco = pd.DataFrame(elenco)
elenco
print(elenco.head(5))

#**********************************************************************************
#**********************************************************************************
#                         B.2 # Cuántos roles o papeles hubo en la película "The Godfather"                               
#**********************************************************************************
#**********************************************************************************

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()

print("Cuántos roles o papeles hubo en la película 'The Godfather'",end = " ")
print(len(elenco[elenco.title == "The Godfather"]))

#**********************************************************************************
#**********************************************************************************
#                         B.3 Cuantos papeles en la pelicula "The Godfather" no estan clasificados en algun valor "n"                               
#**********************************************************************************
#**********************************************************************************

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()

C = elenco[elenco.title == "The Godfather"]
D = C[C.n.isnull()]
print("Los papeles en la pelicula 'The Godfather' no clasificados en algun valor n son:",end=" ")
print(len(D))

#**********************************************************************************
#**********************************************************************************
#                         B.4 Cuantos papeles en la pelicula "The Godfather" no estan clasificados en algun valor "n"
#                             Segundo método
#**********************************************************************************
#**********************************************************************************

# 1.0 # A = Data Frame de papeles en la película "The Godfather"
print("Papeles en la película The Godfather")
A = elenco[elenco.title == "The Godfather"] 

# 2.0 Del DataFrame A Separamos todos los datos de la columna "n" y los guardamos en B
B = A.loc[:,["n"]] #76 datos

# 3.0 Añadimos a B una columna "S_Value" con los datos booleanos de B.isnull()
B["S_Value"] = B.isnull()       # B["S_Value"] =[True,False,...False] 76datos

# 4.0 Separamos todos los datos de la columna "S_Value" que den "False" y los guardamos en C
C = B[B.S_Value == False]
print("Los papeles clasificados en algún valor de n son",end = " ")
print(len(C))

# 5.0 Separamos todos los datos de la columna "S_Value" que den "True" y los guardamos en D
# Estos datos no tienen clasificación en n
D = B[B.S_Value == True]
print("Los papeles sin clasificar en n son",end = " ")
print(len(D))

#**********************************************************************************
#**********************************************************************************
#                         B.5 Mostrar el elenco completo de la pelicula "2001: A Space Odyssey"
#                             ordenado por su clasificasión "n", ignorando los papeles que
#                             no se les asigno ningun valor "n"                          
#**********************************************************************************
#**********************************************************************************

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
doblelin()
 
#************************        PRIMER MÉTODO         **************************

c = elenco
c = c[c.title == "2001: A Space Odyssey"]
c = c[c.n.notnull()].sort_values('n')
print("primer método")
print("El número de personas que forman el elenco de 2001: A Space Odyssey, con valoración n son:",end = " ")
print(len(c))

#************************        SEGUNDO MÉTODO         ****************************
ADF = pd.DataFrame(elenco)                      #Dataframe de elenco
B = ADF[ADF.title == "2001: A Space Odyssey"]   #Dataframe del elenco de la película "2001: A Space Odyssey"

# Ordenamos los valores del DataFrame C por n
C = B.sort_values(by="n",ascending = True)

#seleccionar los datos de C de la columna n, aplicamos isnull() y lo guardamos en D
D = C.loc[:,"n"].isnull()

#En el DataFrame ordenado C, creamos una columna (que llamamos "SValue") con los datos de D:
C["SValue"] = D

#Del DataFrame C, esgogemos los valores que hacen SValue == False (n.isnull() == False), los guardamos en E
E = C[C.SValue == False]
#print(E)
print("segundo método")
print("El número de personas que forman el elenco de 2001: A Space Odyssey, con valoración n son:",end = " ")
print(len(E))

#**********************************************************************************
#**********************************************************************************
#                         B.6 # Mostrar el elenco completo ordenado por la clasificacion "n"
#                              de la pelicula "Dracula" de 1958
#**********************************************************************************
#**********************************************************************************
ADF = pd.DataFrame(elenco)                             #Dataframe de elenco
B = ADF[(ADF.title == "Dracula")&(ADF.year == 1958)]   #Dataframe del elenco de la película dracula
B.sort_values("n")
print("Elenco completo ordenado por la clasificacion n")
print("de la pelicula 'Dracula' de 1958")
print(B.sort_values("n"))

#**********************************************************************************
#**********************************************************************************
#                         B.7 Cuantos papeles fueron listados en la pelicula "The Wizard of Oz" de 1939
#**********************************************************************************
#**********************************************************************************

B = ADF[(ADF.title == "The Wizard of Oz") & (ADF.year == 1939)]
B.sort_values("n")
print("Cuantos papeles fueron listados en la pelicula 'The Wizard of Oz' de 1939:",end = " ")
print(len(B.sort_values("n")))

#**********************************************************************************
#**********************************************************************************
#                         B.8 Cuantos papeles de "Bruce Wayne" han sido hechos en la historia
#                              de las peliculas
#**********************************************************************************
#**********************************************************************************

#print("papeles de Bruce Wayne hechos en la historia de las películas:")
B = ADF[ADF.character == "Bruce Wayne"].sort_values("year")
#print (B)
print("Papeles de Bruce Wayne hechos en la historia de las películas:",end = " ")
print(len(B))

#**********************************************************************************
#**********************************************************************************
#                         B.9 Cuanta gente ha hecho el papel de "Romeo"
#
#**********************************************************************************
#**********************************************************************************

B = ADF[ADF.character == "Romeo"].sort_values("year")
print("Número de personas que han realizado el papel de Romeo:",end = " ")
print(len(B))

#**********************************************************************************
#**********************************************************************************
#                         C.1 Cuantos papeles a hecho "Robert De Niro" en su carrera
#
#**********************************************************************************
#**********************************************************************************

B = ADF[ADF.name == "Robert De Niro"].sort_values("year")
print("Papeles que ha hecho Robert de Niro:",end = " ")
print(len(B))

#**********************************************************************************
#**********************************************************************************
#                         C.2 Listado de papeles de soporte que tuvo el actor "Charlton Heston" en
#                             la decada de los 50's, ordenado por año
#**********************************************************************************
#**********************************************************************************

# Papeles de soporte es: n >= 2

B = ADF[ADF.name == "Charlton Heston"].sort_values("year") #Papeles de Charlton Heston ordenados por año
C = B[B.n >= 2] #Papeles de soporte n>=2
D = C[(C.year >= 1949) & (C.year <= 1959)]
print(D)

#**********************************************************************************
#**********************************************************************************
#                         C.3 Listado de papeles como protagonista que tuvo el actor "Charlton Heston" en
#                             la decada de los 60's, ordenado por año de forma descendente.
#**********************************************************************************
#**********************************************************************************

B = ADF[ADF.name == "Charlton Heston"].sort_values("year",ascending = False) #Papeles de Charlton Heston ordenados por año
C = B[B.n == 1] #Papel estelar n = 1
D = C[(C.year >= 1959) & (C.year <= 1969)]
print(D)

#**********************************************************************************
#**********************************************************************************
#                         C.4 # ¿Cuantos papeles para actores hubo en la decada de los 50's?
#**********************************************************************************
#**********************************************************************************

B = ADF[(ADF.year >= 1950) & (ADF.year <= 1959)]
C = B[B.type == "actor"]
print("Papeles para actores masculinos que hubieron en la década de los 50:",end = " ")
print(len(C))

#**********************************************************************************
#**********************************************************************************
#                         C.5 # ¿Cuantos papeles para actrices hubo en la decada de los 50's?
#**********************************************************************************
#**********************************************************************************

B = ADF[(ADF.year >= 1950) & (ADF.year <= 1959)]
C = B[B.type == "actress"]
print("Papeles para actrices que hubieron en la década de los 50:",end = " ")
print(len(C))

#**********************************************************************************
#**********************************************************************************
#                         C.6 # ¿Cuantos papeles protagonicos existen desde el principio de
#                               la historia filmatografica hasta 1970 ?
#**********************************************************************************
#**********************************************************************************

B = ADF[(ADF.year <= 1970) & (ADF.n == 1)]
print("Papeles protagónicos desde el inicio de la")
print("historia filmatográfica hasta 1970:",end = " ")
print(len(B))
# Out:
# **********************************************************************
# **********************************************************************
# 	 TITULOS
#                                    title  year
# 0                                 Mahler  1974
# 1           Ogon, voda i... mednye truby  1968
# 2  Ana Nojoom bent alasherah wamotalagah  2014
# 3                      Malu de Bicicleta  2010
# 4             Nazareno Apostol: Boy Ahas  1989
# 5                     Ya ba yu xin niang  1971
# 6                            Quicksilver  1986
# 7                     Eko eko azaraku II  1996
# 8    How to Win at Checkers (Every Time)  2015
# 9                         Kanko no machi  1944
# **********************************************************************
# **********************************************************************
# El número de títulos es	 230407
# **********************************************************************
# ...
